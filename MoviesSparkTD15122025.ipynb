# %% [markdown]
# Installer Spark

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark

# %% [markdown]
# Définir les variables d'environnement

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://711094cc40a9:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Exercice 1.1 : Chargement des Données

# %% [markdown]
# Importer les data basics

# %%
# !wget wget https://datasets.imdbws.com/title.basics.tsv.gz
# Out:
# --2025-12-15 08:42:00--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2025-12-15 08:42:00--  https://datasets.imdbws.com/title.basics.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 3.175.207.35, 3.175.207.127, 3.175.207.91, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|3.175.207.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 214986515 (205M) [binary/octet-stream]
# Saving to: ‘title.basics.tsv.gz’
#
# title.basics.tsv.gz 100%[===================>] 205.03M   111MB/s    in 1.8s
#
# 2025-12-15 08:42:03 (111 MB/s) - ‘title.basics.tsv.gz’ saved [214986515/214986515]
#
# FINISHED --2025-12-15 08:42:03--
# Total wall clock time: 2.4s
# Downloaded: 1 files, 205M in 1.8s (111 MB/s)

# %% [markdown]
# Importer les names

# %%
# !wget https://datasets.imdbws.com/name.basics.tsv.gz
# Out:
# --2025-12-15 12:19:40--  https://datasets.imdbws.com/name.basics.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 3.175.207.96, 3.175.207.35, 3.175.207.91, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|3.175.207.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 295789825 (282M) [binary/octet-stream]
# Saving to: ‘name.basics.tsv.gz’
#
# name.basics.tsv.gz  100%[===================>] 282.09M  17.0MB/s    in 18s
#
# 2025-12-15 12:20:00 (15.6 MB/s) - ‘name.basics.tsv.gz’ saved [295789825/295789825]

# %% [markdown]
# Extraire les noms

# %%
with gzip.open('name.basics.tsv.gz', 'rb') as f_in:
    with open('name.basics.tsv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %% [markdown]
# Création du dataset df_names

# %%
df_names = spark.read.csv('./name.basics.tsv', header=True, sep="\t")
df_names.show(2)
# Out:
# +---------+-------------+---------+---------+--------------------+--------------------+
# |   nconst|  primaryName|birthYear|deathYear|   primaryProfession|      knownForTitles|
# +---------+-------------+---------+---------+--------------------+--------------------+
# |nm0000001| Fred Astaire|     1899|     1987|actor,miscellaneo...|tt0072308,tt00504...|
# |nm0000002|Lauren Bacall|     1924|     2014|actress,miscellan...|tt0037382,tt00752...|
# +---------+-------------+---------+---------+--------------------+--------------------+
# only showing top 2 rows

# %% [markdown]
# Récupération dataset df_principals

# %%
# !wget https://datasets.imdbws.com/title.principals.tsv.gz
# Out:
# --2025-12-15 12:23:21--  https://datasets.imdbws.com/title.principals.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 3.175.207.35, 3.175.207.91, 3.175.207.96, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|3.175.207.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 744606566 (710M) [binary/octet-stream]
# Saving to: ‘title.principals.tsv.gz’
#
# title.principals.ts 100%[===================>] 710.11M  14.7MB/s    in 44s
#
# 2025-12-15 12:24:05 (16.2 MB/s) - ‘title.principals.tsv.gz’ saved [744606566/744606566]

# %% [markdown]
# extraction de df_principals

# %%
with gzip.open('title.principals.tsv.gz', 'rb') as f_in:
    with open('title.principals.tsv', 'wb') as f_out:
        shutil
        shutil.copyfileobj(f_in, f_out)

# %% [markdown]
# Déclaration df_principals

# %%
df_principals = spark.read.csv('./title.principals.tsv', header=True, sep="\t")
df_principals.show(2)
# Out:
# +---------+--------+---------+--------+---+----------+
# |   tconst|ordering|   nconst|category|job|characters|
# +---------+--------+---------+--------+---+----------+
# |tt0000001|       1|nm1588970|    self| \N|  ["Self"]|
# |tt0000001|       2|nm0005690|director| \N|        \N|
# +---------+--------+---------+--------+---+----------+
# only showing top 2 rows

# %%
import gzip,shutil

# %%
with gzip.open('title.basics.tsv.gz', 'rb') as f_in:
    with open('title.basics.tsv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %% [markdown]
# Récupération des équipes

# %%
# !wget https://datasets.imdbws.com/title.crew.tsv.gz
# Out:
# --2025-12-15 10:56:40--  https://datasets.imdbws.com/title.crew.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 3.175.207.96, 3.175.207.127, 3.175.207.91, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|3.175.207.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79240391 (76M) [binary/octet-stream]
# Saving to: ‘title.crew.tsv.gz.1’
#
# title.crew.tsv.gz.1 100%[===================>]  75.57M   154MB/s    in 0.5s
#
# 2025-12-15 10:56:40 (154 MB/s) - ‘title.crew.tsv.gz.1’ saved [79240391/79240391]

# %% [markdown]
# *Extraire* crew

# %%
with gzip.open('title.crew.tsv.gz', 'rb') as f_in:
    with open('title.crew.tsv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %% [markdown]
# Afficher le schema Crew

# %%
df_crew = spark.read.csv('./title.crew.tsv', header=True, sep="\t")
df_crew.printSchema()
# Out:
# root
#  |-- tconst: string (nullable = true)
#  |-- directors: string (nullable = true)
#  |-- writers: string (nullable = true)

# %% [markdown]
# Afficher le schema Basics

# %%
# Load data from csv to a dataframe.
# header=True means the first row is a header
# sep=';' means the column are seperated using ''
df_basics = spark.read.csv('./title.basics.tsv', header=True, sep="\t")

df_basics.printSchema()
# Out:
# root
#  |-- tconst: string (nullable = true)
#  |-- titleType: string (nullable = true)
#  |-- primaryTitle: string (nullable = true)
#  |-- originalTitle: string (nullable = true)
#  |-- isAdult: string (nullable = true)
#  |-- startYear: string (nullable = true)
#  |-- endYear: string (nullable = true)
#  |-- runtimeMinutes: string (nullable = true)
#  |-- genres: string (nullable = true)

# %% [markdown]
# Dans df_basics, remplacez les valeurs \N dans la colonne startYear
# par NULL et convertissez cette colonne en type Integer.

# %%
df_basics = df_basics.replace(
    to_replace="\\N",
    value=None,
    subset=["startYear"]
)

df_basics = df_basics.withColumn(
    "startYear",
    df_basics["startYear"].cast("integer")
)

# %% [markdown]
# Filtrer les data

# %%
df_basics.sort("endYear",ascending=False).show(2)
# Out:
# +----------+---------+--------------------+--------------------+-------+---------+-------+--------------+---------+
# |    tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|   genres|
# +----------+---------+--------------------+--------------------+-------+---------+-------+--------------+---------+
# |tt11126122|tvEpisode|Special: Infernal...|Special: Infernal...|      0|     2019|     \N|            24|Animation|
# |tt11126124|tvEpisode|Special: Detectiv...|Special: Detectiv...|      0|     2019|     \N|            \N|Animation|
# +----------+---------+--------------------+--------------------+-------+---------+-------+--------------+---------+
# only showing top 2 rows

# %% [markdown]
# Nombre de ligne de df_basics

# %%
df_basics.count()
# Out:
# 12144623

# %% [markdown]
# Voir les types de films

# %%
df_distinct_titleType = df_basics.select("titleType").distinct()

# Affiche le résultat
df_distinct_titleType.show(truncate=False)
# Out:
# +------------+
# |titleType   |
# +------------+
# |tvSeries    |
# |tvMiniSeries|
# |tvMovie     |
# |tvPilot     |
# |tvEpisode   |
# |movie       |
# |tvSpecial   |
# |video       |
# |videoGame   |
# |tvShort     |
# |short       |
# +------------+

# %% [markdown]
# Filtrez df_basics pour ne conserver que les entrées de type 'movie' et
# 'tvMovie' dans une nouvelle DataFrame df_movies.

# %%
df_movies =df_basics.filter((df_basics["titleType"].contains("movie")) | (df_basics["titleType"].contains('tvMovie')) )
df_movies.show(5)
# Out:
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# |   tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|              genres|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# |tt0000009|    movie|          Miss Jerry|          Miss Jerry|      0|     1894|     \N|            45|             Romance|
# |tt0000147|    movie|The Corbett-Fitzs...|The Corbett-Fitzs...|      0|     1897|     \N|           100|Documentary,News,...|
# |tt0000335|    movie|Soldiers of the C...|Soldiers of the C...|      0|     1900|     \N|            40|     Biography,Drama|
# |tt0000502|    movie|            Bohemios|            Bohemios|      0|     1905|     \N|           100|                  \N|
# ...

# %% [markdown]
# Filtrage du Genre (Focus Historique) : Ajoutez un filtre sur df_movies pour ne conserver
# que les films dont la colonne genres contient le terme 'History' ou 'Documentary'. Nommez
# ce nouveau DataFrame df_historical_selection.

# %%
df_historical_selection = df_movies.filter((df_movies["genres"].contains("History")) | (df_movies["genres"].contains('Documentary')) )
df_historical_selection.show(5)
# Out:
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# |   tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|              genres|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# |tt0000147|    movie|The Corbett-Fitzs...|The Corbett-Fitzs...|      0|     1897|     \N|           100|Documentary,News,...|
# |tt0001059|    movie|O Terremoto de Be...|O Terremoto de Be...|      0|     1909|     \N|            \N|         Documentary|
# |tt0001147|    movie|O Centenário da G...|O Centenário da G...|      0|     1910|     \N|            \N|         Documentary|
# |tt0001163|    movie|    Corrida da Rampa|    Corrida da Rampa|      0|     1910|     \N|            \N|         Documentary|
# ...

# %% [markdown]
# ## Exercice 2.1 : Statistiques Générales sur les Titres

# %% [markdown]
# Conversion en Vue SQL : Créez une vue temporaire SQL pour df_historical_selection
# nommée historical_films.

# %%
df_historical_selection = df_historical_selection.createOrReplaceTempView("historical_films")

# %% [markdown]
# ## Utilisez la vue SQL historical_films ou le DataFrame df_historical_selection :
# 1. Nombre Total : Trouvez le nombre total de titres dans la sélection historique.

# %%
df_historical_selection.count()
# Out:
# 205394

# %% [markdown]
# 2. Titres par Type : Trouvez le nombre de titres par titleType (devrait être majoritairement
# 'movie' et 'tvMovie' après le filtrage).

# %%
df_historical_selection.groupBy("titleType").count().show()
# Out:
# +---------+------+
# |titleType| count|
# +---------+------+
# |  tvMovie| 50856|
# |    movie|154538|
# +---------+------+

# %% [markdown]
# ## Exercice 2.2 : Exploration des Genres

# %% [markdown]
# 1. Popularité des Genres : En utilisant la colonne genres dans df_historical_selection (qui est
# une chaîne de caractères séparée par des virgules) :
#
# Transformation : Séparez les genres de chaque ligne pour les mettre sur des lignes
# séparées (utilisez la fonction Spark SQL explode avec split).
#
# Agrégation : Trouvez les 10 genres les plus populaires (en comptant l'occurrence
# de chaque genre) dans notre sélection historique.

# %%
from pyspark.sql.functions import split, explode, count, desc
df_genres_exploded = df_historical_selection.withColumn(
    "genre_unique",
    explode(split(df_historical_selection["genres"], ","))
)

# Visualisation (basée sur votre exemple)
print("Aperçu du DataFrame après 'explode':")
df_genres_exploded.select("tconst", "genres", "genre_unique").limit(6).show()


# Étape 2 : Agrégation pour trouver le Top 10
# -------------------------------------
df_top_10_genres = df_genres_exploded.groupBy("genre_unique") \
                                     .agg(count("*").alias("count")) \
                                     .orderBy(desc("count")) \
                                     .limit(10)

# Affichage du résultat
print("\nTop 10 des genres les plus populaires :")
df_top_10_genres.show(truncate=False)
# Out:
# Aperçu du DataFrame après 'explode':
# +---------+--------------------+------------+
# |   tconst|              genres|genre_unique|
# +---------+--------------------+------------+
# |tt0000147|Documentary,News,...| Documentary|
# |tt0000147|Documentary,News,...|        News|
# |tt0000147|Documentary,News,...|       Sport|
# |tt0001059|         Documentary| Documentary|
# |tt0001147|         Documentary| Documentary|
# |tt0001163|         Documentary| Documentary|
# +---------+--------------------+------------+
#
#
# Top 10 des genres les plus populaires :
# +------------+------+
# |genre_unique|count |
# +------------+------+
# |Documentary |193353|
# |History     |20776 |
# |Biography   |14393 |
# |Drama       |13524 |
# |Music       |7711  |
# |Sport       |4142  |
# |Adventure   |3228  |
# |War         |3220  |
# |Comedy      |3064  |
# |Family      |2412  |
# +------------+------+

# %% [markdown]
# ## Exercice 2.3 : Longueur des Titres

# %% [markdown]
# 1. Longueurs : Calculez la longueur de la colonne primaryTitle pour chaque film.
# 2. Top/Flop Longueur :
#
# Trouver les 5 titres les plus longs.
#
# Trouver les 5 titres les plus courts.

# %%
from pyspark.sql.functions import length

# Crée une nouvelle colonne 'title_length' contenant la longueur du titre
df_with_length = df_historical_selection.withColumn(
    "title_length",
    length(df_historical_selection["primaryTitle"])
)

# Affiche les colonnes pertinentes pour vérifier le résultat
print("Aperçu du DataFrame avec la longueur du titre :")
df_with_length.select("primaryTitle", "title_length").show(5, truncate=False)


print("### 🥇 Top 5 des titres les plus longs :")
df_longest_titles = df_with_length.orderBy(
    desc("title_length")
).limit(5)

# Affichage des résultats
df_longest_titles.select("primaryTitle", "title_length", "startYear").show(truncate=False)
# Out:
# Aperçu du DataFrame avec la longueur du titre :
# +---------------------------------+------------+
# |primaryTitle                     |title_length|
# +---------------------------------+------------+
# |The Corbett-Fitzsimmons Fight    |29          |
# |O Terremoto de Benavente         |24          |
# |O Centenário da Guerra Peninsular|33          |
# |Corrida da Rampa                 |16          |
# |A Pesca do Bacalhau              |19          |
# +---------------------------------+------------+
# only showing top 5 rows
#
# ### 🥇 Top 5 des titres les plus longs :
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+---------+
# ...

# %% [markdown]
# Récupérer rating

# %%
# !wget wget https://datasets.imdbws.com/title.ratings.tsv.gz
# Out:
# --2025-12-15 10:19:55--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2025-12-15 10:19:55--  https://datasets.imdbws.com/title.ratings.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 3.175.207.127, 3.175.207.96, 3.175.207.35, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|3.175.207.127|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8122231 (7.7M) [binary/octet-stream]
# Saving to: ‘title.ratings.tsv.gz’
#
# title.ratings.tsv.g 100%[===================>]   7.75M  --.-KB/s    in 0.1s
#
# 2025-12-15 10:19:55 (73.7 MB/s) - ‘title.ratings.tsv.gz’ saved [8122231/8122231]
#
# FINISHED --2025-12-15 10:19:55--
# Total wall clock time: 0.5s
# Downloaded: 1 files, 7.7M in 0.1s (73.7 MB/s)

# %% [markdown]
# Extraire les ratings

# %%
with gzip.open('title.ratings.tsv.gz', 'rb') as f_in:
    with open('title.ratings.tsv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %% [markdown]
# Afficher Ratings

# %%
# Load data from csv to a dataframe.
# header=True means the first row is a header
# sep=';' means the column are seperated using ''
df_ratings = spark.read.csv('./title.ratings.tsv', header=True, sep="\t")
df_ratings.show(2)
# Out:
# +---------+-------------+--------+
# |   tconst|averageRating|numVotes|
# +---------+-------------+--------+
# |tt0000001|          5.7|    2188|
# |tt0000002|          5.5|     307|
# +---------+-------------+--------+
# only showing top 2 rows

# %% [markdown]
# ## Exercice 3.1 : Jointure Basique (Films et Ratings)

# %% [markdown]
# 1. Jointure : Joignez df_historical_selection avec df_ratings en utilisant la colonne commune
# tconst avec une jointure interne (inner). Nommez le résultat df_joined_ratings.

# %%
df_joined_ratings = df_historical_selection.join(df_ratings, df_historical_selection["tconst"] == df_ratings["tconst"], "inner")
df_joined_ratings.show(2)
# Out:
# +---------+---------+-------------------+------------------+-------+---------+-------+--------------+-----------------+---------+-------------+--------+
# |   tconst|titleType|       primaryTitle|     originalTitle|isAdult|startYear|endYear|runtimeMinutes|           genres|   tconst|averageRating|numVotes|
# +---------+---------+-------------------+------------------+-------+---------+-------+--------------+-----------------+---------+-------------+--------+
# |tt0006489|    movie|    The Captive God|   The Captive God|      0|     1916|     \N|            50|Adventure,History|tt0006489|          5.6|      37|
# |tt0032711|    movie|The Mannerheim Line|Liniya Mannergeyma|      0|     1940|     \N|            75|  Documentary,War|tt0032711|          6.7|      21|
# +---------+---------+-------------------+------------------+-------+---------+-------+--------------+-----------------+---------+-------------+--------+
# only showing top 2 rows

# %% [markdown]
# 2. Conversion en Vue SQL : Créez une vue temporaire SQL nommée historical_rated_films.

# %%
historical_rated_films = df_joined_ratings.createOrReplaceTempView("historical_rated_films")
df_joined_ratings.show(2)
# Out:
# +---------+---------+-------------------+------------------+-------+---------+-------+--------------+-----------------+---------+-------------+--------+
# |   tconst|titleType|       primaryTitle|     originalTitle|isAdult|startYear|endYear|runtimeMinutes|           genres|   tconst|averageRating|numVotes|
# +---------+---------+-------------------+------------------+-------+---------+-------+--------------+-----------------+---------+-------------+--------+
# |tt0006489|    movie|    The Captive God|   The Captive God|      0|     1916|     \N|            50|Adventure,History|tt0006489|          5.6|      37|
# |tt0032711|    movie|The Mannerheim Line|Liniya Mannergeyma|      0|     1940|     \N|            75|  Documentary,War|tt0032711|          6.7|      21|
# +---------+---------+-------------------+------------------+-------+---------+-------+--------------+-----------------+---------+-------------+--------+
# only showing top 2 rows

# %% [markdown]
# ## Exercice 3.2 : Requêtes Basées sur les Notes

# %% [markdown]
# Utilisez la vue SQL historical_rated_films :
# 1. Les Parfaits (Note 10) :
#
# Rechercher les 5 films historiques ayant un averageRating de 10.0 et qui ont au
# moins 100 votes (numVotes).

# %%
five_top_rated_films = spark.sql("SELECT * FROM historical_rated_films WHERE averageRating = 10.0 AND numVotes >= 20 ORDER BY averageRating DESC LIMIT 5")
five_top_rated_films.show(truncate =False)
# Out:
# +----------+---------+----------------------------------------------+----------------------------------------------+-------+---------+-------+--------------+-----------+----------+-------------+--------+
# |tconst    |titleType|primaryTitle                                  |originalTitle                                 |isAdult|startYear|endYear|runtimeMinutes|genres     |tconst    |averageRating|numVotes|
# +----------+---------+----------------------------------------------+----------------------------------------------+-------+---------+-------+--------------+-----------+----------+-------------+--------+
# |tt10663998|movie    |Widow of the Revolution: The Anna Larina Story|Widow of the Revolution: The Anna Larina Story|0      |2000     |\N     |\N            |Documentary|tt10663998|10.0         |28      |
# ...

# %% [markdown]
# 2. Les Sélections Intermédiaires (Années Spécifiques) :
#
# Rechercher tous les films historiques ayant un score (averageRating) entre 5 et 6
# (exclus) et dont l'année de début (startYear) est entre 1980 et 1999 (inclus).

# %%
df_intermediate_selection = spark.sql("SELECT * FROM historical_rated_films WHERE averageRating > 5.0 AND averageRating < 6.0 AND startYear BETWEEN 1980 AND 1999")
df_intermediate_selection.show()
# Out:
# +----------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+----------+-------------+--------+
# |    tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|              genres|    tconst|averageRating|numVotes|
# +----------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+----------+-------------+--------+
# | tt0080617|    movie|Deutschland Priva...|Deutschland Priva...|      0|     1980|     \N|            85|         Documentary| tt0080617|          5.7|      63|
# | tt0444062|    movie|Enquête sur un fi...|Enquête sur un fi...|      0|     1991|     \N|            51|         Documentary| tt0444062|          5.9|      22|
# | tt0248832|    movie|The Great Indian ...|The Great Indian ...|      0|     1991|     \N|            96|Documentary,Histo...| tt0248832|          5.8|      92|
# ...

# %% [markdown]
# ## Exercice 3.3 : Jointure Triple (Films, Acteurs et Ratings)

# %% [markdown]
# Pour identifier les acteurs clés dans notre sélection :
# 1. Triple Jointure : Réalisez une jointure enchaînée :
# --
# df_joined_ratings (votre jointure historique film-rating)
# --
# Jointure avec df_principals sur tconst.
# --
# Jointure avec df_names sur la colonne d'identifiant de la personne (nconst dans
# df_principals et nconst dans df_names).
# --
# Filtrez df_principals pour ne retenir que les lignes où category est 'actor' ou 'actress'.
# --
# Nommez le résultat df_actor_ratings.

# %%
# df_actor_ratings = df_joined_ratings.join(df_principals, df_joined_ratings["tconst"] == df_principals["tconst"], "inner")

df_actor_ratings = df_joined_ratings.join(df_principals, ["tconst"], "inner")
df_actor_ratings = df_actor_ratings.join(df_names, ["nconst"], "inner")

df_actor_ratings = df_actor_ratings.filter((df_actor_ratings["category"] == "actor") | (df_actor_ratings["category"] == "actress"))

df_actor_ratings.show(2)
# df_actor_ratings = df_actor_ratings = df_actor_ratings.join(df_names, df_actor_ratings["nconst"] == df_names["n const"], "inner")
# df_actor_ratings = df_actor_ratings.filter((df_actor_ratings["category"] == "actor") | (df_actor_ratings  ["category"] == "actress"))
# df_actor_ratings.show(2)
# Out:
# +---------+---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+---------+-------------+--------+--------+--------+---+--------------------+--------------+---------+---------+--------------------+--------------------+
# |   nconst|   tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|              genres|   tconst|averageRating|numVotes|ordering|category|job|          characters|   primaryName|birthYear|deathYear|   primaryProfession|      knownForTitles|
# +---------+---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+---------+-------------+--------+--------+--------+---+--------------------+--------------+---------+---------+--------------------+--------------------+
# ...

# %% [markdown]
# 2. Conversion en Vue SQL : Créez une vue temporaire SQL nommée historical_actors_ratings.

# %%
historical_actors_ratings = df_actor_ratings.createOrReplaceTempView("historical_actors_ratings")

# %% [markdown]
# ## Exercice 3.4 : Requêtes Basées sur les Acteurs
# Utilisez la vue SQL historical_actors_ratings :

# %% [markdown]
# Acteurs à Note 5 :
#
# Rechercher les 5 noms d'acteurs/actrices (primaryName de df_names) qui ont joué
# dans le plus grand nombre de films historiques ayant exactement un rating de 5.0.

# %%
five_actors_with_highest_ratings = spark.sql("SELECT primaryName, COUNT(*) AS num_films FROM historical_actors_ratings WHERE averageRating = 5.0 GROUP BY primaryName ORDER BY num_films DESC LIMIT 5")
five_actors_with_highest_ratings.show(truncate=False)
# Out:
# +-------------------+---------+
# |primaryName        |num_films|
# +-------------------+---------+
# |Gianfelice Imparato|2        |
# |Toni Servillo      |2        |
# |Marco Macor        |2        |
# |Matt Eisenberg     |2        |
# |Geraldine Chaplin  |2        |
# +-------------------+---------+

# %% [markdown]
# 2. Recherche par Acteur :
# o
# Rechercher tous les films (titre et année) avec l'acteur 'Ben Affleck' (utilisez son
# nom exact) qui ont obtenu un averageRating entre 5 et 10 (inclus). Triez par année
# décroissante.

# %%
with_ben_affleck = spark.sql("SELECT primaryTitle, startYear FROM historical_actors_ratings WHERE primaryName = 'Ben Affleck' AND averageRating BETWEEN 5.0 AND 10.0 ORDER BY startYear DESC")
with_ben_affleck.show(truncate=False)
# Out:
# +------------------------+---------+
# |primaryTitle            |startYear|
# +------------------------+---------+
# |The Last Duel           |2021     |
# |Argo                    |2012     |
# |The Curse of the Bambino|2003     |
# +------------------------+---------+

# %% [markdown]
# ## Get Spark Session Information
#
# ### Subtask:
# Retrieve and display key information about the current SparkSession, such as the application name, application ID, and Spark master URL.

# %% [markdown]
# **Reasoning**:
# The subtask requires retrieving and displaying the SparkSession's application name, application ID, and master URL. These can be accessed through the `spark.sparkContext` object.

# %%
print(f"Spark Application Name: {spark.sparkContext.appName}")
print(f"Spark Application ID: {spark.sparkContext.applicationId}")
print(f"Spark Master URL: {spark.sparkContext.master}")
# Out:
# Spark Application Name: pyspark-shell
# Spark Application ID: local-1765787943609
# Spark Master URL: local[*]

# %% [markdown]
# ## Get Spark Configuration and Resources
#
# ### Subtask:
# Access and display the Spark configuration properties, including the number of cores allocated for the Spark application. For a local Spark instance, this will reflect the resources used by the local process.

# %% [markdown]
# **Reasoning**:
# The subtask requires accessing and displaying Spark configuration properties and the number of allocated cores. I will use `spark.sparkContext.getConf().getAll()` to retrieve all configuration properties and then iterate through them to print. For the number of allocated cores, I will use `spark.sparkContext.defaultParallelism` as it reflects the default parallelism for a local instance.

# %%
print("Spark Configuration Properties:")
for key, value in spark.sparkContext.getConf().getAll():
    print(f"  {key}: {value}")

print(f"\nNumber of allocated cores (default parallelism): {spark.sparkContext.defaultParallelism}")
# Out:
# Spark Configuration Properties:
#   spark.driver.port: 44461
#   spark.app.startTime: 1765787942217
#   spark.rdd.compress: True
#   spark.serializer.objectStreamReset: 100
#   spark.master: local[*]
#   spark.submit.pyFiles:
#   spark.executor.id: driver
#   spark.submit.deployMode: client
#   spark.sql.warehouse.dir: file:/content/spark-warehouse
#   spark.ui.showConsoleProgress: true
#   spark.app.name: pyspark-shell
#   spark.driver.host: 711094cc40a9
#   spark.app.id: local-1765787943609
#
# Number of allocated cores (default parallelism): 2
